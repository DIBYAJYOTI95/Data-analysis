# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\DIBYAJYOTI DAS\Desktop\data.csv")

# %%
print(df.head())
print(df.tail())
# Out:
#    age          job  marital  education  balance housing loan Personal loan  \
# 0   30   unemployed  married    primary     1787           no            no
# 1   33     services  married  secondary     4789          yes           yes
# 2   35   management   single   tertiary     1350          yes            no
# 3   30   management  married   tertiary     1476          yes           yes
# 4   59  blue-collar  married  secondary        0          yes            no
#
#     contact  day month  duration(s)  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct           79         1     -1         0  unknown  no
# 1  cellular   11   may          220         1    339         4  failure  no
# 2  cellular   16   apr          185         1    330         1  failure  no
# 3   unknown    3   jun          199         4     -1         0  unknown  no
# 4   unknown    5   may          226         1     -1         0  unknown  no
#       age            job  marital  education  balance housing loan  \
# 4516   33       services  married  secondary     -333          yes
# 4517   57  self-employed  married   tertiary    -3313          yes
# 4518   57     technician  married  secondary      295           no
# 4519   28    blue-collar  married  secondary     1137           no
# 4520   44   entrepreneur   single   tertiary     1136          yes
#
#      Personal loan   contact  day month  duration(s)  campaign  pdays  \
# 4516            no  cellular   30   jul          329         5     -1
# 4517           yes   unknown    9   may          153         1     -1
# 4518            no  cellular   19   aug          151        11     -1
# 4519            no  cellular    6   feb          129         4    211
# 4520           yes  cellular    3   apr          345         2    249
#
#       previous poutcome   y
# 4516         0  unknown  no
# 4517         0  unknown  no
# 4518         0  unknown  no
# 4519         3    other  no
# 4520         7    other  no

# %%
print(df.describe())
# Out:
#                age       balance          day  duration(s)     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            4521 non-null   int64
#  1   job            4521 non-null   object
#  2   marital        4521 non-null   object
#  3   education      4521 non-null   object
#  4   balance        4521 non-null   int64
#  5   housing loan   4521 non-null   object
#  6   Personal loan  4521 non-null   object
#  7   contact        4521 non-null   object
#  8   day            4521 non-null   int64
#  9   month          4521 non-null   object
#  10  duration(s)    4521 non-null   int64
#  11  campaign       4521 non-null   int64
#  12  pdays          4521 non-null   int64
#  13  previous       4521 non-null   int64
#  14  poutcome       4521 non-null   object
#  15  y              4521 non-null   object
# dtypes: int64(7), object(9)
# memory usage: 565.3+ KB
# None

# %%
print("Shape of the dataset: ",df.shape)
# Out:
# Shape of the dataset:  (4521, 16)

# %%
print("Missing values: ",df.isnull().sum())
print("Unknown values in each column: ")
for col in df.columns:
    if df[col].dtype == 'object':
        print(col, ":", (df[col] == 'unknown').sum())
# Out:
# Missing values:  age              0
# job              0
# marital          0
# education        0
# balance          0
# housing loan     0
# Personal loan    0
# contact          0
# day              0
# month            0
# duration(s)      0
# campaign         0
# pdays            0
# previous         0
# poutcome         0
# y                0
# dtype: int64
# Unknown values in each column:
# job : 38
# marital : 0
# education : 187
# housing loan : 0
# Personal loan : 0
# contact : 1324
# month : 0
# poutcome : 3705
# y : 0

# %%
print("Count of yes/no: ",df['y'].value_counts())
# Out:
# Count of yes/no:  y
# no     4000
# yes     521
# Name: count, dtype: int64

# %%
sns.countplot(x='y',data=df)
plt.title("Target variable count")
plt.show()

# %%
num_cols = ['age','balance','day','campaign','pdays','previous']

# %%
for col in num_cols:
    plt.figure()
    plt.hist(df[col],bins=30,color='lightgreen',edgecolor='black') 
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='Blues')
plt.title("Correlation Heatmap")
plt.show()

# %%
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='y',y=col,data=df)
    plt.title(f"{col} by target (y)")
    plt.tight_layout()
    plt.show()
